# %% [markdown]
# # Уменьшение размерности датасета

# %% [markdown]
# ## Подключение библиотек и определение используемых алгоритмов

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml, load_digits
from sklearn import datasets, decomposition, manifold, preprocessing
import umap

# %%
UMAP = umap.UMAP(n_components=2)
TSNE= manifold.TSNE(n_components=2)
SVD = decomposition.TruncatedSVD(n_components=2)
PCA = decomposition.PCA(n_components=2)

algorithms = [
   {'function': UMAP, 'name': 'UMAP'},
   {'function': TSNE, 'name': 'TSNE'},
   {'function': SVD, 'name': 'SVD'},
   {'function': PCA, 'name': 'PCA'}
]

# %% [markdown]
# ## Применение алгоритмов к датасетам

# %%
def print_algorithms_results(data_id, load_function,caption):
    fig, axs = plt.subplots(1,4, figsize=(16,4))
    fig.suptitle(f"{caption} dataset", fontsize=16)
    if data_id == None:
        dataset, dataset_labels = load_function(return_X_y=True, as_frame=False)
    else:
        dataset, dataset_labels = load_function(data_id=data_id,return_X_y=True,as_frame=False)
    for i, algorithm in enumerate(algorithms):
        results = algorithm['function'].fit_transform(dataset)
        color = dataset_labels.astype(int)
        axs[i].scatter(results[:,0], results[:,1], c=color)
        axs[i].set_xlabel(algorithm['name'])

# %%
print_algorithms_results(554,fetch_openml,'mnist')
# Out:
# C:\Users\andrew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\andrew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
print_algorithms_results(40996,fetch_openml, 'fmnist')
# Out:
# C:\Users\andrew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\andrew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
print_algorithms_results(40685,fetch_openml, 'shuttle')
# Out:
# C:\Users\andrew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\andrew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
print_algorithms_results(None, load_digits,'pendigits')
# Out:
# C:\Users\andrew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\andrew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
